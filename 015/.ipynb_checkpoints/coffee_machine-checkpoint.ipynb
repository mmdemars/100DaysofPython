# %%
MENU = {
    "espresso": {
        "ingredients": {
            "water": 50,
            "milk": 0,
            "coffee": 18,
        },
        "cost": 1.5,
    },
    "latte": {
        "ingredients": {
            "water": 200,
            "milk": 150,
            "coffee": 24,
        },
        "cost": 2.5,
    },
    "cappuccino": {
        "ingredients": {
            "water": 250,
            "milk": 100,
            "coffee": 24,
        },
        "cost": 3.0,
    }
}

resources = {
    "water": 300,
    "milk": 200,
    "coffee": 100,
}

money = 0

# %%
# needs to be able to print a report of available resources
# check that resources are there when a drink is ordered
# process coins
# check transaction

# %%
def coffee_machine():
    power = True
    enough_cash = True
    
    def fill_order(order):
        for i in MENU:
            if i == order:
                print(i)
                print("order recieved")
                drink = i
                if MENU[drink]["ingredients"]["water"] <= resources["water"]:
                    if MENU[drink]["ingredients"]["milk"] <= resources["milk"]:
                        if MENU[drink]["ingredients"]["coffee"] <= resources["coffee"]:
                            cash_money = count_coins()
                            if cash_money >= MENU[drink]["cost"]:
                                dispense()
                                profit = sort_money(cash_money, drink)
                                print(f"Enjoy your {drink}")
                                return profit
                            else:
                                print(f"Sorry, that's not enough money. Return ${cash_money}.")
                        else:
                            print("There are not enough resources to make your drink.")
                    else:
                        print("There are not enough resources to make your drink.")
                else:
                    print("There are not enough resources to make your drink.")


    def count_coins():
        quarters = int(input("How many quarters? "))
        dimes = int(input("How many dimes? "))
        nickels = int(input("How many nickels? "))
        pennies = int(input("How many pennies? "))
        cash_money = round((quarters * 0.25) + (dimes * 0.1) + (nickels*0.05) + (pennies *0.01), 2)
        print(f"{cash_money} recieved")
        return cash_money


    def dispense():
        resources["water"] = (resources["water"]) - (MENU[order]["ingredients"]["water"])
        resources["milk"] = (resources["milk"]) - (MENU[order]["ingredients"]["milk"])
        resources["coffee"] = (resources["coffee"]) - (MENU[order]["ingredients"]["coffee"])


    def sort_money(cash_money, drink):
        change = round(cash_money - MENU[drink]["cost"],2)
        profit = MENU[drink]["cost"]
        print(f"Your change is {change}")
        return(profit)
       
            
    

    while power:
        global money

        order = input("What is your order? latte, cappuccino, or espresso ")
        if order == "report":
            print(f"Water: {resources['water']}ml")
            print(f"Milk: {resources['milk']}ml")
            print(f"Coffee: {resources['coffee']}g")
            print(f"Money: ${money}")
        elif order == "off":
            print("Machine shutting down.")
            power = False
        elif order == "latte" or "cappuccino" or "espresso":
            profit = fill_order(order)
            if profit:
                money += profit
        else:
            print("User Error. Machine shutting down.")
            power = False


coffee_machine()
# Out:
# What is your order? latte, cappuccino, or espresso latte
# latte
# order recieved
# How many quarters? 4
# How many dimes? 4
# How many nickels? 4
# How many pennies? 4
# 1.64 recieved
# Sorry, that's not enough money. Return $1.64.
# What is your order? latte, cappuccino, or espresso latte
# latte
# order recieved
# How many quarters? 5
# How many dimes? 5
# How many nickels? 5
# How many pennies? 5
# 2.05 recieved
# Sorry, that's not enough money. Return $2.05.
# What is your order? latte, cappuccino, or espresso latte
# latte
# order recieved
# How many quarters? 6
# How many dimes? 6
# How many nickels? 6
# How many pennies? 6
# 2.46 recieved
# Sorry, that's not enough money. Return $2.46.
# What is your order? latte, cappuccino, or espresso latte
# latte
# order recieved
# How many quarters? 8
# How many dimes? 10
# How many nickels? 20
# How many pennies? 5
# 4.05 recieved
# Your change is 1.55
# Enjoy your latte
# What is your order? latte, cappuccino, or espresso report
# ...

# %%
print(money)
print(resources)
# Out:
# 4.0
# {'water': 0, 'milk': 50, 'coffee': 40}
